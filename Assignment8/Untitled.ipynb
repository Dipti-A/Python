# %%
import pandas as pd
import math

# %%
df = pd.read_csv("houses.csv")

df.columns=['A','Price','C','D','E','F','G','H','I','J','K','L','M','N','O','P']
#df.head()
df['Price'].describe()
#df.describe()
# Out:
# count    9.999900e+04
# mean     1.743880e+05
# std      3.514649e+05
# min      1.500000e+02
# 25%      7.400000e+04
# 50%      1.290000e+05
# 75%      2.070000e+05
# max      4.846572e+07
# Name: Price, dtype: float64

# %%
print("Min Price -",df['Price'].min())
print("Med Price -",df['Price'].median())
print("Max Price -",df['Price'].max())

df['Price'].hist(bins=20,log=True)
plt.xlabel('Frequency')
plt.ylabel('Price')
plt.title('Property price graph')
# Out:
# Min Price - 150
# Med Price - 129000.0
# Max Price - 48465717
# Text(0.5, 1.0, 'Property price graph')

# %%
#df.plot()
